# %% [markdown]
# # 5. Explicação da Previsão do Preço a partir da Base de Dados

# %% [markdown]
# ## 5.1 Preparação dos dados

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

# %%
# carregando a base de dados de treinamento
df = pd.read_csv('/content/drive/MyDrive/Desafio Cientista de Dados - Indicium/cars_train.csv', encoding='UTF-16', delimiter='\t')

# %%
# verificando o numeros de linhas e colunas do dataframe
df.shape
# Out:
# (29584, 29)

# %%
df.dtypes
# Out:
# num_fotos              int64
# marca                 object
# modelo                object
# versao                object
# ano_de_fabricacao      int64
# ano_modelo             int64
# hodometro            float64
# cambio                object
# num_portas             int64
# tipo                  object
# blindado              object
# cor                   object
# tipo_vendedor         object
# cidade_vendedor       object
# estado_vendedor       object
# anunciante            object
# entrega_delivery        bool
# troca                   bool
# preco                float64
# dtype: object

# %%
# configurando a indexação do dataframe pelo atributo id
df.set_index('id', inplace=True)

# %%
# excluindo os atributos irrelevantes para uso no modelo preditivo
colunas_para_excluir = ['veiculo_alienado', 'elegivel_revisao', 'dono_aceita_troca',
                                       'veiculo_único_dono', 'revisoes_concessionaria', 'ipva_pago',
                                       'veiculo_licenciado', 'garantia_de_fábrica', 'revisoes_dentro_agenda']
df = df.drop(columns=colunas_para_excluir)

# %%
# preenchendo os valores faltantes do atributo num_fotos com o valor mediano das amostras.
valor = df.describe()['num_fotos']['50%']
df['num_fotos'].fillna(valor, inplace=True)

# %%
# convertendo os valores do tipo float para int dos atributos num_fotos e ano_modelo
df['num_fotos'] = df['num_fotos'].astype(int)
df['ano_modelo'] = df['ano_modelo'].astype(int)

# %%
# convertendo os valores do tipo object para int do atributo blindado
df['blindado'] = df['blindado'].replace({'S': 1, 'N': 0})

# %%
# convertendo os valores do tipo bool para int dos atributos entrega_delivery e troca
df['entrega_delivery'] = df['entrega_delivery'].replace({True: 1, False: 0})
df['troca'] = df['troca'].replace({True: 1, False: 0})

# %%
# excluindo os atributos não considerados como atributos previsores para o modelo preditivo.
colunas_para_excluir = ['modelo', 'versao', 'cidade_vendedor', 'hodometro']
df = df.drop(columns=colunas_para_excluir)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29584 entries, 300716223898539419613863097469899222392 to 171781413417552881896009715888472310172
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_fotos          29584 non-null  int64
#  1   marca              29584 non-null  object
#  2   ano_de_fabricacao  29584 non-null  int64
#  3   ano_modelo         29584 non-null  int64
#  4   cambio             29584 non-null  object
#  5   num_portas         29584 non-null  int64
#  6   tipo               29584 non-null  object
#  7   blindado           29584 non-null  int64
#  8   cor                29584 non-null  object
#  9   tipo_vendedor      29584 non-null  object
#  10  estado_vendedor    29584 non-null  object
#  11  anunciante         29584 non-null  object
#  12  entrega_delivery   29584 non-null  int64
#  13  troca              29584 non-null  int64
#  14  preco              29584 non-null  float64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 4.6+ MB

# %%
df.nunique()
# Out:
# num_fotos               14
# marca                   40
# ano_de_fabricacao       35
# ano_modelo              17
# cambio                   7
# num_portas               3
# tipo                     7
# blindado                 2
# cor                      7
# tipo_vendedor            2
# estado_vendedor         25
# anunciante               4
# entrega_delivery         2
# troca                    2
# preco                29584
# dtype: int64

# %% [markdown]
# ## 5.2 Seleção das features

# %%
def split_dataframe(df, target):
  X, y = df.drop(columns=[target], axis=1).values, df[target].values
  return X, y

# %%
# # separando a variável df em duas partes: variáveis X e y
X, y = split_dataframe(df, 'preco')
print(X.shape, type(X))
print(y.shape, type(y))
# Out:
# (29584, 14) <class 'numpy.ndarray'>
# (29584,) <class 'numpy.ndarray'>

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder(sparse=False)

# aplicando a codificação one-hot na variável X
onehot_encoder.fit(X)
X_onehot = onehot_encoder.transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_onehot.shape
# Out:
# (29584, 167)

# %%
from sklearn.neighbors import LocalOutlierFactor

# identificando e eliminando de forma automatica outliers na base de dados de treinamento
lof = LocalOutlierFactor()
yhat = lof.fit_predict(X_onehot)

# %%
# selecionando todas as linhas que não são outliers
mask = yhat != -1
X_onehot, y = X_onehot[mask, :], y[mask]
print(X_onehot.shape, type(X_onehot))
print(y.shape, type(y))
# Out:
# (24260, 167) <class 'numpy.ndarray'>
# (24260,) <class 'numpy.ndarray'>

# %%
# aplicando a normalização dos dados na variável y

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
y_norm = scaler.fit_transform(y.reshape(-1, 1))

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline

# criando um dicionario de modelos RFE
def get_models(num_features):
	models = dict()
	end = num_features//2
	for value in range(2, end):
		rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select = value)
		model = DecisionTreeRegressor()
		models[str(value)] = Pipeline(steps=[('s', rfe), ('m',model)])
	return models

# %%
from sklearn.model_selection import cross_val_score, RepeatedKFold

# avaliando um determinado modelo usando validação cruzada
def evaluate_model(model, X, y):
	cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=1)
	scores = cross_val_score(model, X, y, scoring = 'neg_mean_squared_error', cv = cv, n_jobs = -1, error_score = 'raise')
	return scores

# %%
# criando os modelos RFE a serem avaliados por meio da validação cruizada
num_features = X_onehot.shape[1]
models = get_models(num_features)

# %%
import numpy as np

# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	scores = evaluate_model(model, X_onehot, y_norm)
	results.append(scores)
	names.append(name)
	print(f'{name}: RMSE = {np.sqrt(np.abs(np.mean(scores))):.5f} ({np.sqrt(np.abs(np.std(scores))):.5f})')
# Out:
# 2: RMSE = 0.05510 (0.01447)
# 3: RMSE = 0.05182 (0.01380)
# 4: RMSE = 0.05078 (0.01323)
# 5: RMSE = 0.04976 (0.01325)
# 6: RMSE = 0.04906 (0.01315)
# 7: RMSE = 0.04830 (0.01274)
# 8: RMSE = 0.04780 (0.01262)
# 9: RMSE = 0.04743 (0.01295)
# 10: RMSE = 0.04716 (0.01393)
# 11: RMSE = 0.04684 (0.01387)
# 12: RMSE = 0.04616 (0.01389)
# 13: RMSE = 0.04571 (0.01344)
# 14: RMSE = 0.04579 (0.01504)
# 15: RMSE = 0.04565 (0.01528)
# 16: RMSE = 0.04581 (0.01610)
# 17: RMSE = 0.04593 (0.01743)
# 18: RMSE = 0.04632 (0.01682)
# 19: RMSE = 0.04682 (0.01581)
# 20: RMSE = 0.04595 (0.01606)
# 21: RMSE = 0.04711 (0.01789)
# 22: RMSE = 0.04681 (0.01631)
# 23: RMSE = 0.04736 (0.01812)
# 24: RMSE = 0.04727 (0.01440)
# 25: RMSE = 0.04742 (0.01823)
# 26: RMSE = 0.04720 (0.01704)
# 27: RMSE = 0.04757 (0.01719)
# 28: RMSE = 0.04813 (0.01842)
# 29: RMSE = 0.04824 (0.01729)
# 30: RMSE = 0.04863 (0.01674)
# 31: RMSE = 0.04916 (0.01561)
# 32: RMSE = 0.04982 (0.01711)
# 33: RMSE = 0.04931 (0.01852)
# 34: RMSE = 0.04931 (0.01773)
# 35: RMSE = 0.05063 (0.01646)
# 36: RMSE = 0.05014 (0.01662)
# 37: RMSE = 0.05018 (0.01612)
# 38: RMSE = 0.04984 (0.01729)
# 39: RMSE = 0.05095 (0.01678)
# 40: RMSE = 0.05130 (0.01581)
# 41: RMSE = 0.05091 (0.01720)
# 42: RMSE = 0.05019 (0.01533)
# 43: RMSE = 0.05067 (0.01482)
# 44: RMSE = 0.05091 (0.01324)
# 45: RMSE = 0.05156 (0.01422)
# 46: RMSE = 0.05127 (0.01505)
# 47: RMSE = 0.05232 (0.01496)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-ff3f876ae1e1> in <cell line: 5>()
#       4 results, names = list(), list()
#       5 for name, model in models.items():
# ----> 6         scores = evaluate_model(model, X_onehot, y_norm)
#       7         results.append(scores)
#       8         names.append(name)
#
# <ipython-input-73-78fe3d5d418d> in evaluate_model(model, X, y)
#       4 def evaluate_model(model, X, y):
#       5         cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=1)
# ----> 6         scores = cross_val_score(model, X, y, scoring = 'neg_mean_squared_error', cv = cv, n_jobs = -1, error_score = 'raise')
#       7         return scores
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     513     scorer = check_scoring(estimator, scoring=scoring)
#     514
# --> 515     cv_results = cross_validate(
#     516         estimator=estimator,
#     517         X=X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264     # independent, and that it is pickle-able.
#     265     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266     results = parallel(
#     267         delayed(_fit_and_score)(
#     268             clone(estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1942         next(output)
#    1943
# -> 1944         return output if self.return_generator else list(output)
#    1945
#    1946     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1585
#    1586             with self._backend.retrieval_context():
# -> 1587                 yield from self._retrieve()
#    1588
#    1589         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1697                 (self._jobs[0].get_status(
#    1698                     timeout=self.timeout) == TASK_PENDING)):
# -> 1699                 time.sleep(0.01)
#    1700                 continue
#    1701
#
# KeyboardInterrupt:

# %%
# identificando as colunas selecionadas pelo método RFE
rfe = RFE(estimator = DecisionTreeRegressor(), n_features_to_select=15)
rfe.fit(X_onehot, y_norm)
for value in range(num_features):
	print(f'Column = {value}, Selected = {rfe.support_[value]}, Rank = {rfe.ranking_[value]:.2f}')
# Out:
# Column = 0, Selected = False, Rank = 11.00
# Column = 1, Selected = False, Rank = 62.00
# Column = 2, Selected = False, Rank = 153.00
# Column = 3, Selected = False, Rank = 112.00
# Column = 4, Selected = False, Rank = 76.00
# Column = 5, Selected = False, Rank = 33.00
# Column = 6, Selected = False, Rank = 28.00
# Column = 7, Selected = False, Rank = 7.00
# Column = 8, Selected = False, Rank = 22.00
# Column = 9, Selected = False, Rank = 44.00
# Column = 10, Selected = False, Rank = 68.00
# Column = 11, Selected = False, Rank = 87.00
# Column = 12, Selected = False, Rank = 48.00
# Column = 13, Selected = False, Rank = 119.00
# Column = 14, Selected = False, Rank = 129.00
# Column = 15, Selected = False, Rank = 26.00
# Column = 16, Selected = True, Rank = 1.00
# Column = 17, Selected = False, Rank = 140.00
# Column = 18, Selected = False, Rank = 79.00
# Column = 19, Selected = False, Rank = 25.00
# Column = 20, Selected = False, Rank = 106.00
# Column = 21, Selected = False, Rank = 71.00
# Column = 22, Selected = False, Rank = 114.00
# Column = 23, Selected = False, Rank = 147.00
# Column = 24, Selected = False, Rank = 143.00
# Column = 25, Selected = True, Rank = 1.00
# Column = 26, Selected = False, Rank = 45.00
# Column = 27, Selected = False, Rank = 47.00
# Column = 28, Selected = False, Rank = 20.00
# Column = 29, Selected = False, Rank = 134.00
# Column = 30, Selected = False, Rank = 124.00
# Column = 31, Selected = False, Rank = 51.00
# Column = 32, Selected = False, Rank = 63.00
# Column = 33, Selected = False, Rank = 66.00
# Column = 34, Selected = True, Rank = 1.00
# Column = 35, Selected = False, Rank = 73.00
# Column = 36, Selected = False, Rank = 139.00
# Column = 37, Selected = False, Rank = 80.00
# Column = 38, Selected = True, Rank = 1.00
# Column = 39, Selected = False, Rank = 81.00
# Column = 40, Selected = False, Rank = 46.00
# Column = 41, Selected = False, Rank = 70.00
# Column = 42, Selected = False, Rank = 55.00
# Column = 43, Selected = True, Rank = 1.00
# Column = 44, Selected = True, Rank = 1.00
# Column = 45, Selected = False, Rank = 56.00
# Column = 46, Selected = False, Rank = 135.00
# Column = 47, Selected = False, Rank = 110.00
# Column = 48, Selected = False, Rank = 65.00
# Column = 49, Selected = False, Rank = 93.00
# Column = 50, Selected = False, Rank = 24.00
# Column = 51, Selected = False, Rank = 77.00
# Column = 52, Selected = False, Rank = 29.00
# Column = 53, Selected = False, Rank = 52.00
# Column = 54, Selected = False, Rank = 149.00
# Column = 55, Selected = False, Rank = 150.00
# Column = 56, Selected = False, Rank = 136.00
# Column = 57, Selected = False, Rank = 127.00
# Column = 58, Selected = False, Rank = 126.00
# Column = 59, Selected = False, Rank = 131.00
# Column = 60, Selected = False, Rank = 123.00
# Column = 61, Selected = False, Rank = 122.00
# Column = 62, Selected = False, Rank = 111.00
# Column = 63, Selected = False, Rank = 115.00
# Column = 64, Selected = False, Rank = 116.00
# Column = 65, Selected = False, Rank = 103.00
# Column = 66, Selected = False, Rank = 98.00
# Column = 67, Selected = False, Rank = 102.00
# Column = 68, Selected = False, Rank = 104.00
# Column = 69, Selected = False, Rank = 91.00
# Column = 70, Selected = False, Rank = 108.00
# Column = 71, Selected = False, Rank = 99.00
# Column = 72, Selected = False, Rank = 121.00
# Column = 73, Selected = False, Rank = 97.00
# Column = 74, Selected = False, Rank = 100.00
# Column = 75, Selected = False, Rank = 94.00
# Column = 76, Selected = False, Rank = 109.00
# Column = 77, Selected = False, Rank = 92.00
# Column = 78, Selected = False, Rank = 53.00
# Column = 79, Selected = False, Rank = 14.00
# Column = 80, Selected = False, Rank = 39.00
# Column = 81, Selected = False, Rank = 21.00
# Column = 82, Selected = False, Rank = 42.00
# Column = 83, Selected = False, Rank = 37.00
# Column = 84, Selected = False, Rank = 6.00
# Column = 85, Selected = False, Rank = 10.00
# Column = 86, Selected = True, Rank = 1.00
# Column = 87, Selected = False, Rank = 30.00
# Column = 88, Selected = False, Rank = 107.00
# Column = 89, Selected = False, Rank = 151.00
# Column = 90, Selected = False, Rank = 148.00
# Column = 91, Selected = False, Rank = 142.00
# Column = 92, Selected = False, Rank = 95.00
# Column = 93, Selected = False, Rank = 18.00
# Column = 94, Selected = True, Rank = 1.00
# Column = 95, Selected = True, Rank = 1.00
# Column = 96, Selected = True, Rank = 1.00
# Column = 97, Selected = True, Rank = 1.00
# Column = 98, Selected = False, Rank = 49.00
# Column = 99, Selected = False, Rank = 9.00
# Column = 100, Selected = False, Rank = 27.00
# Column = 101, Selected = False, Rank = 12.00
# Column = 102, Selected = False, Rank = 31.00
# Column = 103, Selected = False, Rank = 13.00
# Column = 104, Selected = False, Rank = 67.00
# Column = 105, Selected = False, Rank = 141.00
# Column = 106, Selected = False, Rank = 89.00
# Column = 107, Selected = False, Rank = 84.00
# Column = 108, Selected = False, Rank = 5.00
# Column = 109, Selected = False, Rank = 138.00
# Column = 110, Selected = False, Rank = 72.00
# Column = 111, Selected = True, Rank = 1.00
# Column = 112, Selected = False, Rank = 117.00
# Column = 113, Selected = False, Rank = 32.00
# Column = 114, Selected = False, Rank = 120.00
# Column = 115, Selected = False, Rank = 82.00
# Column = 116, Selected = False, Rank = 36.00
# Column = 117, Selected = False, Rank = 57.00
# Column = 118, Selected = False, Rank = 145.00
# Column = 119, Selected = False, Rank = 69.00
# Column = 120, Selected = True, Rank = 1.00
# Column = 121, Selected = False, Rank = 17.00
# Column = 122, Selected = True, Rank = 1.00
# Column = 123, Selected = False, Rank = 43.00
# Column = 124, Selected = False, Rank = 78.00
# Column = 125, Selected = True, Rank = 1.00
# Column = 126, Selected = False, Rank = 4.00
# Column = 127, Selected = False, Rank = 144.00
# Column = 128, Selected = False, Rank = 61.00
# Column = 129, Selected = False, Rank = 19.00
# Column = 130, Selected = False, Rank = 152.00
# Column = 131, Selected = False, Rank = 146.00
# Column = 132, Selected = False, Rank = 35.00
# Column = 133, Selected = False, Rank = 64.00
# Column = 134, Selected = False, Rank = 132.00
# Column = 135, Selected = False, Rank = 75.00
# Column = 136, Selected = False, Rank = 96.00
# Column = 137, Selected = False, Rank = 59.00
# Column = 138, Selected = False, Rank = 86.00
# Column = 139, Selected = False, Rank = 125.00
# Column = 140, Selected = False, Rank = 38.00
# Column = 141, Selected = False, Rank = 128.00
# Column = 142, Selected = False, Rank = 101.00
# Column = 143, Selected = False, Rank = 105.00
# Column = 144, Selected = False, Rank = 41.00
# Column = 145, Selected = False, Rank = 16.00
# Column = 146, Selected = False, Rank = 88.00
# Column = 147, Selected = False, Rank = 90.00
# Column = 148, Selected = False, Rank = 74.00
# Column = 149, Selected = False, Rank = 118.00
# Column = 150, Selected = False, Rank = 83.00
# Column = 151, Selected = False, Rank = 34.00
# Column = 152, Selected = False, Rank = 23.00
# Column = 153, Selected = False, Rank = 137.00
# Column = 154, Selected = False, Rank = 133.00
# Column = 155, Selected = False, Rank = 15.00
# Column = 156, Selected = False, Rank = 85.00
# Column = 157, Selected = False, Rank = 3.00
# Column = 158, Selected = False, Rank = 113.00
# Column = 159, Selected = False, Rank = 130.00
# Column = 160, Selected = False, Rank = 50.00
# Column = 161, Selected = False, Rank = 2.00
# Column = 162, Selected = False, Rank = 58.00
# Column = 163, Selected = False, Rank = 40.00
# Column = 164, Selected = False, Rank = 60.00
# Column = 165, Selected = False, Rank = 8.00
# Column = 166, Selected = False, Rank = 54.00

# %%
# definindo as colunas selecionadas pelo método RFE como sendo as features
select_features = [16, 25, 34, 38, 43, 44, 86, 94, 95, 96, 97, 111, 120, 122, 125]
X_onehot_features = X_onehot[:, select_features]
print(X_onehot_features.shape)
# Out:
# (24260, 15)

# %% [markdown]
# ## 5.3 Divisão dos Dados

# %%
from sklearn.model_selection import train_test_split

# Dividir o conjunto de dados em treinamento e teste (80% para treinamento, 20% para teste)
X_train, X_test, y_train_norm, y_test_norm = train_test_split(X_onehot_features , y_norm, test_size = 0.20, random_state=1)

# %% [markdown]
# ## 5.4 Seleção e Treinamento do Modelo

# %%
# !pip install autokeras
# Out:
# Collecting autokeras
#   Downloading autokeras-1.1.0-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from autokeras) (23.1)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from autokeras) (2.12.0)
# Collecting keras-tuner>=1.1.0 (from autokeras)
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 9.5 MB/s eta 0:00:00
# Collecting keras-nlp>=0.4.0 (from autokeras)
#   Downloading keras_nlp-0.6.0-py3-none-any.whl (576 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 576.5/576.5 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from autokeras) (1.5.3)
# Collecting keras-core (from keras-nlp>=0.4.0->autokeras)
#   Downloading keras_core-0.1.3-py3-none-any.whl (851 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.9/851.9 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.4.0->autokeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.4.0->autokeras) (1.22.4)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.4.0->autokeras) (2022.10.31)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.4.0->autokeras) (13.4.2)
# Collecting tensorflow-text (from keras-nlp>=0.4.0->autokeras)
#   Downloading tensorflow_text-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner>=1.1.0->autokeras) (2.27.1)
# Collecting kt-legacy (from keras-tuner>=1.1.0->autokeras)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.56.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.4.13)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.32.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->autokeras) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->autokeras) (2022.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->autokeras) (0.41.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.8.0->autokeras) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.8.0->autokeras) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (2.3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (3.4)
# Collecting namex (from keras-core->keras-nlp>=0.4.0->autokeras)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-nlp>=0.4.0->autokeras) (0.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nlp>=0.4.0->autokeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nlp>=0.4.0->autokeras) (2.14.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text->keras-nlp>=0.4.0->autokeras) (0.14.0)
# Collecting tensorflow>=2.8.0 (from autokeras)
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 1.2 MB/s eta 0:00:00
# Collecting keras<2.14,>=2.13.1 (from tensorflow>=2.8.0->autokeras)
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.8 MB/s eta 0:00:00
# Collecting tensorboard<2.14,>=2.13 (from tensorflow>=2.8.0->autokeras)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 28.1 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow>=2.8.0->autokeras)
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 8.2 MB/s eta 0:00:00
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow>=2.8.0->autokeras)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nlp>=0.4.0->autokeras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (3.2.2)
# Installing collected packages: namex, kt-legacy, typing-extensions, tensorflow-estimator, keras, keras-tuner, keras-core, tensorboard, tensorflow, tensorflow-text, keras-nlp, autokeras
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# Successfully installed autokeras-1.1.0 keras-2.13.1 keras-core-0.1.3 keras-nlp-0.6.0 keras-tuner-1.3.5 kt-legacy-1.0.5 namex-0.0.7 tensorboard-2.13.0 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-text-2.13.0 typing-extensions-4.5.0

# %%
from autokeras import StructuredDataRegressor

# criando e treinando o modelo AutoKeras para a regressão
regressor = StructuredDataRegressor(max_trials=10, overwrite=True)
regressor.fit(X_train, y_train_norm, verbose = 0)
# Out:
# Using TensorFlow backend

# %% [markdown]
# ## 5.5 Avaliação do Modelo Treinado

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# avaliando o modelo regressor com os dados de teste
mse, _ = regressor.evaluate(X_test,  y_test_norm, verbose=0)
rmse = np.sqrt(mse)
print(f'RMSE: {rmse:5f}')
# Out:
# RMSE: 0.044925

# %% [markdown]
# ## 5.6 Precificando com o Modelo de melhor desempenho

# %%
# obtendo o modelo de melhor desempenho
model = regressor.export_model()

# %%
# resumindo a arquitetura e parametros do modelo de melhor desempenho
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 15)]              0
#
#  multi_category_encoding (M  (None, 15)                0
#  ultiCategoryEncoding)
#
#  normalization (Normalizati  (None, 15)                31
#  on)
#
#  dense (Dense)               (None, 128)               2048
#
#  re_lu (ReLU)                (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  re_lu_1 (ReLU)              (None, 32)                0
#
#  regression_head_1 (Dense)   (None, 1)                 33
#
# =================================================================
# Total params: 6240 (24.38 KB)
# Trainable params: 6209 (24.25 KB)
# Non-trainable params: 31 (128.00 Byte)
# _________________________________________________________________

# %%
# save the best performing model to file
model.save('/content/drive/MyDrive/Desafio Cientista de Dados - Indicium/model_auto', save_format='tf')

# %%
# carregando a base de dados de treinamento
df_test = pd.read_csv('/content/drive/MyDrive/Desafio Cientista de Dados - Indicium/cars_test.csv', encoding='UTF-16', delimiter='\t')

# %%
# verificando o numeros de linhas e colunas do dataframe
df_test.shape
# Out:
# (9862, 28)

# %%
df_test.isnull().sum()
# Out:
# id                            0
# num_fotos                    60
# marca                         0
# modelo                        0
# versao                        0
# ano_de_fabricacao             0
# ano_modelo                    0
# hodometro                     0
# cambio                        0
# num_portas                    0
# tipo                          0
# blindado                      0
# cor                           0
# tipo_vendedor                 0
# cidade_vendedor               0
# estado_vendedor               0
# anunciante                    0
# entrega_delivery              0
# troca                         0
# elegivel_revisao              0
# dono_aceita_troca          2554
# veiculo_único_dono         6387
# revisoes_concessionaria    6795
# ipva_pago                  3298
# veiculo_licenciado         4518
# garantia_de_fábrica        8439
# revisoes_dentro_agenda     7869
# veiculo_alienado           9862
# dtype: int64

# %%
df_test.dtypes
# Out:
# id                          object
# num_fotos                  float64
# marca                       object
# modelo                      object
# versao                      object
# ano_de_fabricacao            int64
# ano_modelo                 float64
# hodometro                  float64
# cambio                      object
# num_portas                   int64
# tipo                        object
# blindado                    object
# cor                         object
# tipo_vendedor               object
# cidade_vendedor             object
# estado_vendedor             object
# anunciante                  object
# entrega_delivery              bool
# troca                         bool
# elegivel_revisao              bool
# dono_aceita_troca           object
# veiculo_único_dono          object
# revisoes_concessionaria     object
# ipva_pago                   object
# veiculo_licenciado          object
# garantia_de_fábrica         object
# revisoes_dentro_agenda      object
# veiculo_alienado           float64
# dtype: object

# %%
# configurando a indexação do dataframe pelo atributo id
df_test.set_index('id', inplace=True)

# %%
# excluindo os atributos irrelevantes para uso no modelo preditivo
colunas_para_excluir = ['veiculo_alienado', 'elegivel_revisao', 'dono_aceita_troca',
                                       'veiculo_único_dono', 'revisoes_concessionaria', 'ipva_pago',
                                       'veiculo_licenciado', 'garantia_de_fábrica', 'revisoes_dentro_agenda']
df_test = df_test.drop(columns=colunas_para_excluir)

# %%
# preenchendo os valores faltantes do atributo num_fotos com o valor mediano das amostras.
valor = df_test.describe()['num_fotos']['50%']
df_test['num_fotos'].fillna(valor, inplace=True)

# %%
# convertendo os valores do tipo float para int dos atributos num_fotos e ano_modelo
df_test['num_fotos'] = df_test['num_fotos'].astype(int)
df_test['ano_modelo'] = df_test['ano_modelo'].astype(int)

# %%
# convertendo os valores do tipo object para int do atributo blindado
df_test['blindado'] = df_test['blindado'].replace({'S': 1, 'N': 0})

# %%
# convertendo os valores do tipo bool para int dos atributos entrega_delivery e troca
df_test['entrega_delivery'] = df_test['entrega_delivery'].replace({True: 1, False: 0})
df_test['troca'] = df_test['troca'].replace({True: 1, False: 0})

# %%
# excluindo os atributos não considerados como atributos previsores para o modelo preditivo.
colunas_para_excluir = ['modelo', 'versao', 'cidade_vendedor', 'hodometro']
df_test = df_test.drop(columns=colunas_para_excluir)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9862 entries, 13518783164498355150900635905895481162 to 332784980027104367393384305973418103109
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_fotos          9862 non-null   int64
#  1   marca              9862 non-null   object
#  2   ano_de_fabricacao  9862 non-null   int64
#  3   ano_modelo         9862 non-null   int64
#  4   cambio             9862 non-null   object
#  5   num_portas         9862 non-null   int64
#  6   tipo               9862 non-null   object
#  7   blindado           9862 non-null   int64
#  8   cor                9862 non-null   object
#  9   tipo_vendedor      9862 non-null   object
#  10  estado_vendedor    9862 non-null   object
#  11  anunciante         9862 non-null   object
#  12  entrega_delivery   9862 non-null   int64
#  13  troca              9862 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 1.1+ MB

# %%
df_test.nunique()
# Out:
# num_fotos            13
# marca                39
# ano_de_fabricacao    34
# ano_modelo           17
# cambio                7
# num_portas            3
# tipo                  8
# blindado              2
# cor                   6
# tipo_vendedor         2
# estado_vendedor      24
# anunciante            4
# entrega_delivery      2
# troca                 2
# dtype: int64

# %%
# # separando a variável df em duas partes: variáveis X e y
X_test = df_test.values
print(X_test.shape, type(X_test))
# Out:
# (9862, 14) <class 'numpy.ndarray'>

# %%
# aplicando a codificação one-hot na variável X
onehot_encoder.fit(X_test)
X_test_onehot = onehot_encoder.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_test_onehot.shape
# Out:
# (9862, 163)

# %%
X_test_onehot_features = X_test_onehot[:, select_features]
X_test_onehot_features.shape
# Out:
# (9862, 15)

# %%
# Fazer as previsões no conjunto de teste
y_predicted_norm = model.predict(X_test_onehot_features)
# Out:
# 309/309 [==============================] - 1s 4ms/step

# %%
y_predicted = scaler.inverse_transform(y_predicted_norm)

# %%
print(y_predicted.shape, type(y_predicted))
# Out:
# (9862, 1) <class 'numpy.ndarray'>

# %%
id_predicted = df_test.index.to_numpy()
print(id_predicted.shape, type(id_predicted))
# Out:
# (9862,) <class 'numpy.ndarray'>

# %%
predicted_array = np.column_stack((id_predicted, y_predicted))

# %%
df_predicted = pd.DataFrame(predicted_array, columns=['id', 'preco'])

# %%
df_predicted.head()
# Out:
#                                         id          preco
# 0   13518783164498355150900635905895481162  130342.359375
# 1  299896161723793383246777788797566040330  130342.359375
# 2  316180649972302128246133616457018378621     274244.125
# 3  222527157104148385909188217274642813298  112290.882812
# 4  160460343059850745858546502614838368036  130342.359375

# %%
df_predicted.to_csv('/content/drive/MyDrive/Desafio Cientista de Dados - Indicium/predicted.csv', index=False)
